# %% [markdown]
# # II. Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("company_sales_data.csv")

# %% [markdown]
# ## 1.Matplotlib package and plotting different graphs

# %% [markdown]
# ### Read Total profit of all months and show it using a line plot

# %%
profitList = df ['total_profit'].tolist()
monthList  = df ['month_number'].tolist()
plt.plot(monthList, profitList)
plt.xlabel('Month')
plt.ylabel('Profit')
plt.title('profit per month')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Get total profit of all months and show line plot with the following Style properties

# %%
 
profitList = df ['total_profit'].tolist()
monthList  = df ['month_number'].tolist()
plt.plot(monthList, profitList, label = 'Profit data', color='orange', marker='o', markerfacecolor='black', linestyle=':', linewidth=2)
plt.xlabel('Month Number')
plt.ylabel('Profit')
plt.title('Sales data')
plt.legend()
plt.show()

# %% [markdown]
# ###  Read all product sales data and show it  using a multiline plot

# %%
monthList  = df ['month_number'].tolist()
faceCremSalesData   = df ['facecream'].tolist()
faceWashSalesData   = df ['facewash'].tolist()
toothPasteSalesData = df ['toothpaste'].tolist()
bathingsoapSalesData   = df ['bathingsoap'].tolist()
shampooSalesData   = df ['shampoo'].tolist()
moisturizerSalesData = df ['moisturizer'].tolist()

plt.plot(monthList, faceCremSalesData,   label = 'Facecream', marker='o', linewidth=2)
plt.plot(monthList, faceWashSalesData,   label = 'FaceWash',  marker='o', linewidth=2)
plt.plot(monthList, toothPasteSalesData, label = 'ToothPaste', marker='o', linewidth=2)
plt.plot(monthList, bathingsoapSalesData, label = 'Bathingsoap', marker='o', linewidth=2)
plt.plot(monthList, shampooSalesData, label = 'Shampoo', marker='o', linewidth=2)
plt.plot(monthList, moisturizerSalesData, label = 'Moisturizer', marker='o', linewidth=2)

plt.xlabel('Month')
plt.ylabel('Sales units')
plt.legend(loc='upper left')
plt.title('Sales data')
plt.show()

# %% [markdown]
# ### Read moisturizer sales data of each month and show it using a scatter plot

# %%
from turtle import color


monthList  = df ['month_number'].tolist()
moisturizerSalesData = df ['moisturizer'].tolist()
plt.scatter(monthList, moisturizerSalesData, label = 'moisturizer Sales data', color='red')
plt.xlabel('Month')
plt.ylabel('Number of units Sold')
plt.title('moisturizer Sales data')
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# ### Read moisturizer and shampoo product sales data and show it using the bar chart

# %%
monthList  = df ['month_number'].tolist()
faceCremSalesData   = df ['moisturizer'].tolist()
faceWashSalesData   = df ['shampoo'].tolist()

plt.bar([a-0.25 for a in monthList], faceCremSalesData, width= 0.25, label = 'moisturizer sales data', align='edge', color='black')
plt.bar([a+0.25 for a in monthList], faceWashSalesData, width= -0.25, label = 'facewash sales data', align='edge', color='orange')
plt.xlabel('Month')
plt.ylabel('Sales units')
plt.legend(loc='upper right')
plt.title('Sales data')
plt.title('moisturizer and shampoo sales data')
plt.show()

# %% [markdown]
# ### Read the total profit of each month and show it using the histogram to see the most common profit ranges

# %%
profitList = df ['total_profit'].tolist()
labels = ['low', 'average', 'Good', 'Best']
plt.hist(profitList, label = 'Profit data', edgecolor='black')
plt.xlabel('profit range')
plt.ylabel('Actual Profit')
plt.legend(loc='upper left')
plt.title('Profit data')
plt.show()

# %% [markdown]
# ### Calculate total sale data for last year for each product and show it using a Pie chart

# %%
monthList  = df ['month_number'].tolist()
labels = ['FaceCream', 'FaseWash', 'ToothPaste', 'Bathing soap', 'Shampoo', 'Moisturizer']
salesData   = [df ['facecream'].sum(), df ['facewash'].sum(), df ['toothpaste'].sum(), df ['bathingsoap'].sum(), df ['shampoo'].sum(), df ['moisturizer'].sum()]
plt.axis("equal")
plt.pie(salesData, labels=labels, autopct='%1.1f%%')
plt.legend(loc='lower right')
plt.title('Sales data')
plt.show()

# %% [markdown]
# ## Adding text to different chart types and working with batches

# %% [markdown]
# ### a)Adding emoji as a label to the graph type ###

# %%
plt.plot(monthList, faceCremSalesData,   label = 'Facecream', marker='$\U0001F601$', ms=15, linewidth=2)
plt.plot(monthList, faceWashSalesData,   label = 'FaceWash',  marker='$\U0001F602$', ms=15, linewidth=2)
plt.plot(monthList, toothPasteSalesData, label = 'ToothPaste', marker='$\U0001F603$', ms=15, linewidth=2)
plt.plot(monthList, bathingsoapSalesData, label = 'Bathingsoap', marker='$\U0001F604$', ms=15, linewidth=2)
plt.plot(monthList, shampooSalesData, label = 'Shampoo', marker='$\U0001F605$', ms=15, linewidth=2)
plt.plot(monthList, moisturizerSalesData, label = 'Moisturizer', marker='$\U0001F606$', ms=15, linewidth=2)

plt.xlabel('Month')
plt.ylabel('Sales units')
plt.legend(loc='upper left')
plt.title('Sales data')
plt.show()

# %% [markdown]
# ###  b)Adding text "Average chart of a company " x axis name , y axis name

# %%
profitList = df ['total_profit'].tolist()
profitList = [i/6 for i in profitList]
monthList  = df ['month_number'].tolist()
plt.plot(monthList, profitList)
plt.xlabel('Month')
plt.ylabel('Average Profit')
plt.title('Average chart of a company')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.plot(monthList, faceWashSalesData,   label = 'FaceWash',  marker='o', ms=10, linewidth=2)
plt.plot(monthList, moisturizerSalesData, label = 'Moisturizer', marker='o', ms=10, linewidth=2)

plt.xlabel('Month')
plt.ylabel('Sales units')
plt.legend(loc='upper left')
plt.title('Sales data')
plt.show()

# %%
plt.plot(monthList, faceWashSalesData,  '-s', label = 'FaceWash', ms=10, linewidth=2)
plt.plot(monthList, moisturizerSalesData,'-s', label = 'Moisturizer',  ms=10, linewidth=2)

plt.xlabel('Month')
plt.ylabel('Sales units')
plt.legend(loc='upper left')
plt.title('Sales data')
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt


fig = plt.figure()
ax = fig.add_subplot(111)

f = sum(faceWashSalesData)
m = sum(moisturizerSalesData)
rect = matplotlib.patches.Rectangle((-200, -100),f, m,color ='green')
#poly = matplotlib.patches.Polygon((-2000, -1000),f, m,color ='blue')
cir = matplotlib.patches.Circle((-1000, -500),f,color ='red')

ax.add_patch(rect)
#ax.add_patch(poly)
ax.add_patch(cir)
plt.xlim([-40000, 40000])
plt.ylim([-40000, 40000])

plt.show()
