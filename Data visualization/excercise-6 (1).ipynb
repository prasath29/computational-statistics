# %%
# Read Total profit of all months and show it using a line plot
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("E:\HP\company_sales_data.csv")
profitList = df ['total_profit'].tolist()
monthList  = df ['month_number'].tolist()
plt.plot(monthList, profitList, label = 'Month-wise Profit data')
plt.xlabel('Month number')
plt.ylabel('Profit')
plt.xticks(monthList)
plt.title('Company profit per month')
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.legend()
plt.show()

# %%
# Get total profit of all months and show line plot with the following Style properties 
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("E:\HP\company_sales_data.csv")
profitList = df ['total_profit'].tolist()
monthList  = df ['month_number'].tolist()

plt.plot(monthList, profitList, label = 'Profit data of last year',  color='green', marker='o', markerfacecolor='red', linestyle='-', linewidth=3)
      
plt.xlabel('Month Number')
plt.ylabel('Profit')
plt.title('Company Sales data')
plt.xticks(monthList)
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.legend()
plt.show()

# %%
#  Read all product sales data and show it  using a multiline plot
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("E:\HP\company_sales_data.csv")
monthList  = df ['month_number'].tolist()
faceCremSalesData   = df ['facecream'].tolist()
faceWashSalesData   = df ['facewash'].tolist()
toothPasteSalesData = df ['toothpaste'].tolist()
bathingsoapSalesData   = df ['bathingsoap'].tolist()
shampooSalesData   = df ['shampoo'].tolist()
moisturizerSalesData = df ['moisturizer'].tolist()

plt.plot(monthList, faceCremSalesData,   label = 'Face cream', marker='o', linewidth=3)
plt.plot(monthList, faceWashSalesData,   label = 'Face Wash',  marker='o', linewidth=3)
plt.plot(monthList, toothPasteSalesData, label = 'ToothPaste', marker='o', linewidth=3)
plt.plot(monthList, bathingsoapSalesData, label = 'Bathing soap', marker='o', linewidth=3)
plt.plot(monthList, shampooSalesData, label = 'ShampooSales', marker='o', linewidth=3)
plt.plot(monthList, moisturizerSalesData, label = 'Moisturizer', marker='o', linewidth=3)

plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.xticks(monthList)
plt.yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])
plt.title('Sales data')
plt.show()

# %%
# Read facecream sales data of each month and show it using a scatter plot
from turtle import color
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("E:\HP\company_sales_data.csv")
monthList  = df ['month_number'].tolist()
toothPasteSalesData = df ['facecream'].tolist()
plt.scatter(monthList, faceCremSalesData, label = 'Face cream Sales data')
plt.xlabel('Month Number')
plt.ylabel('Number of units Sold')
plt.title(' Face cream Sales data')
plt.xticks(monthList)
plt.legend(loc = 'upper right')
plt.show()

# %%
# Read face cream and bathingsoap product sales data and show it using the bar chart
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("E:\HP\company_sales_data.csv")
monthList  = df ['month_number'].tolist()
faceCremSalesData   = df ['facecream'].tolist()
faceWashSalesData   = df ['bathingsoap'].tolist()

plt.bar([a-0.25 for a in monthList], faceCremSalesData, width= 0.25, label = 'Face Cream sales data', align='edge')
plt.bar([a+0.25 for a in monthList], bathingsoapSalesData, width= -0.25, label = 'bathingsoap sales data', align='edge')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.title(' Sales data')

plt.xticks(monthList)
plt.grid(True, linewidth= 1, linestyle="--")
plt.title('Facewash and bathingsoap sales data')
plt.show()

# %%
# Read the total profit of each month and show it using the histogram to see the most common profit ranges
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("E:\HP\company_sales_data.csv")
profitList = df ['total_profit'].tolist()
labels = ['low', 'average', 'Good', 'Best']
profit_range = [150000, 175000, 200000, 225000, 250000, 300000, 350000,400000]
plt.hist(profitList,profit_range ,label = 'Profit data',edgecolor='black',color='green')
plt.xlabel('profit range')
plt.ylabel('Actual Profit')
plt.legend(loc='upper right')
plt.xticks(profit_range)
plt.title('Profit data')
plt.show()

# %%
# Calculate total sale data for last year for each product and show it using a Pie chart
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("E:\HP\company_sales_data.csv")
monthList  = df ['month_number'].tolist()
labels = ['FaceCream', 'FaseWash', 'ToothPaste', 'Bathing soap', 'Shampoo', 'Moisturizer']
salesData   = [df ['facecream'].sum(), df ['facewash'].sum(), df ['toothpaste'].sum(), df ['bathingsoap'].sum(), df ['shampoo'].sum(), df ['moisturizer'].sum()]
plt.axis("equal")
plt.pie(salesData, labels=labels, autopct='%1.1f%%')
plt.legend(loc='lower right')
plt.title('Sales data')
plt.show()
